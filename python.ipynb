# %% [markdown]
# <a href="https://colab.research.google.com/github/leejeongeun97/dataAnalysis/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 다중 주석 단축키: ctrl+/ (안될때  Ctrl+shift 영역 지정 했다가 ctrl+/하면 됨)
# 들여쓰기 영역지정  tab
# 들여쓰기 취소 Shift + tab
#
#
# 여러줄 주석 '''
#
# 리스트[] 딕셔너리 {'a':'222',...}
# dice=[0,0,0,0,0,0]
# dice.index(max(dice))
#
# 튜플 ()변경 불가
# 집합  set {} 중복된게 안들어감
#
# True, False
#
# 데이터 타입
# int, float, bool, str,list,tuple
#
# 데이터 공백제거  temp.strip()
#
# %나머지 //몫 **제곱
#
# ------if
# str(x) if num%3== 0 else x
# if not line : break
#
# -----print
# print(a_list, end=' ')
#  print("=> 성공" if result == 0 else "=> 실패")
#
# -----random
# import random
# score = [random.randint(1,100) for _ in range(5)]
# score = random.sample(range(1,100),5)
#
# ------for
# fruits=['사과','포도','딸기','키위']
# for idx, fruit in enumerate(fruits):
#
# for i in range (1,101):
# for v in {1,2,3,3,4,5,3}:
#
# dic ={1:'사과',2:'포도'}
# for key, value in dic.items():
#
# a=[(1,2),(3,4),(5,6)]
# for first,last in a :
#
# for _ in range(3):
#
#
#
# n= int(input('합계를 구할 숫자 입력:'))
# hap = sum([i for i in range(1,n+1,2)])
# hap = sum([i for i in range(0,1000+1) if i%3==0])
#
#
# num_list =list(input("숫자를 여러개 입력하세요 : "))
#
# num_list =input("숫자를 여러개 입력하세요 : ")
# for i, in num_list :
#     print('\u2605'*int(i)*2)
#
# room_num= int(input("방 개수:"))
# roomlist = [0 for _ in range(room_num)]
#
# max_list=[idx+1 for idx,v in enumerate(dice) if v == list_max]
#
# cells=[(row,col)for row in rows for col in cols]
#
# tuplist = list(zip(foods,sides))
# dic = dict(zip(foods,sides))
#
# //랜덤
# x = [1, 3, 5, 4, 2]
#  random.shuffle(x)
# random.choice(x)
# random.randint(10,20) # 10~20이상사이의 임의의 정수 1개
# random.randrange(10,20,2)  # 10~20미만의 2간격의 임의의 정수 1개
# random.uniform(10,20) start <= N <= end 사이의 실수
#
# random.random()
# random.sample(range(1,46), 6)  # 임의의 값 선택 (중복불허)
# print(f"로또 번호는: {sorted(random.sample(range(1,46),6))}")
#
# int n
# _i= int(str(n)[0])
#
# #def  : 함수정의
# 한줄 함수 정의 : lambda
# hap= lambda num1, num2: num1+num2
#
# #lambda
# myList=[1,2,3,4,5]
# add10=lambda num: num+10
# myList = list(map(add10,myList))
#
# mylist1=[1,2,3,4,5]
# mylist2=[2,4,6,8,10]
# func=lambda x,y: x*y
# mylist= list(map(func,mylist1,mylist2))
#
# 파일 입출력
# f= open('C:\python\새파일2.txt','w')  # C꼭 대문자
# f= open('./새파일.txt','a')
#
# line= f.read()  통으로 읽기
# for line in f.readlines():
#     print(line.strip())
# line = f.readline() #한줄만 읽기
# line = f.readlines()
# f.close()
#
# //with -- f.close를 따로 사용하지 않고 사용이 끝나면 자동으로 닫힘
# with open('./새파일22.txt','w') as f:
#     f.write("사랑해요, 파이썬")
#
# import os
# print(f'현재위치 : {os.getcwd()}')
# print(f'현재위치 리스트 : {os.listdir()}')
# os.chdir('../')   #전폴더로 이동
# print(f'현재위치 리스트 : {os.listdir()}')
#
# if os.path.isfile(file):
#     os.remove(file)
#     print(f'{file}이 삭제되었습니다')
#
#
# ##클래스
# class name:
#  a= 0  //변수
# def fun_name(self,val) :
# 	내용
# def __init__(self)
# 	내용
