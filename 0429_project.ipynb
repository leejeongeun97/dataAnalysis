# %% [markdown]
# <a href="https://colab.research.google.com/github/leejeongeun97/dataAnalysis/blob/main/0429_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename= '과실생산량_성과수미과수__20240429192116.csv'
df= pd.read_csv(filename, encoding='utf-8')

df.index= df.시도별
df.drop('시도별',axis=1, inplace=True)
df.head()

# plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['figure.figsize'] = (10, 5)

# y = df.columns
# x = df.iloc[1][0]

# print(x)
# print(y)

# 2.막대 그래프 그리기
# plt.bar(x,y)

# 3. 그래프 꾸미기
# plt.title('사과 생산량')     # 그래프 제목
# plt.xlabel('년도')     # x축 이름
# plt.ylabel('생산량')# y축 이름
# plt.xticks(rotation=45)     # X축 레이블 회전
# plt.show()
# Out:
#              1980        1981        1982        1983        1984        1985  \
# 시도별
# 시도별    사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)
# 계          410047      523145      527141      586023      528175      532571
# 서울특별시           -           -          11          62          91          98
# 부산광역시           -           -          41           -           -           -
# 대구광역시           -           -        8683        7508        6799        7197
#
#              1986        1987        1988        1989  ...        2014  \
# 시도별                                                    ...
# 시도별    사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  ...  사과:생산량 (톤)
# 계          537737      556160      640333      676016  ...      474712
# 서울특별시          74          36          43          74  ...           0
# 부산광역시           -           -           -           -  ...          25
# 대구광역시        7565        5151        4643        5872  ...        1262
#
#              2015        2016        2017        2018        2019        2020  \
# 시도별
# 시도별    사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)
# 계          582846      576369      545349      475303      535324      422115
# 서울특별시           0           0           0           0           0           0
# 부산광역시          27          89          13          15          55          28
# 대구광역시        1548        1627        1322         509         378         647
#
#              2021        2022        2023
# 시도별
# 시도별    사과:생산량 (톤)  사과:생산량 (톤)  사과:생산량 (톤)
# 계          515931      566041      394428
# 서울특별시           0           0           0
# 부산광역시          45          49         108
# 대구광역시         752         990         641
#
# [5 rows x 44 columns]

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['figure.figsize'] = (10, 5)

x = df.columns
y = list(df.iloc[1].apply(int))

print(x)
print(y)
# Out:
# Index(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')
# [410047, 523145, 527141, 586023, 528175, 532571, 537737, 556160, 640333, 676016, 628947, 542015, 694766, 615991, 616505, 715982, 651406, 651778, 459010, 490152, 488960, 403583, 433165, 365354, 357180, 367517, 407621, 435686, 470865, 494491, 460285, 379541, 394596, 493701, 474712, 582846, 576369, 545349, 475303, 535324, 422115, 515931, 566041, 394428]

# %%
# 2.막대 그래프 그리기
plt.bar(x,y)


plt.title('사과 생산량')     # 그래프 제목
plt.xlabel('년도')     # x축 이름
plt.ylabel('생산량')# y축 이름
plt.xticks(rotation=45)     # X축 레이블 회전
plt.show()

# %%
# 선 그래프
plt.rcParams['figure.figsize']=(13,10)

for i in range(10,18):
    df.iloc[i]= df.iloc[i].str.replace('-','0')
    y = list(df.iloc[i].apply(int))
    if df.index[i] == '경상북도' :
        kb_y=df.iloc[i].apply(int)
    plt.plot(x,y,'o',linestyle='solid',label=df.index[i])
plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.show()
print(kb_y)
# Out:
# 1980    256590
# 1981    341237
# 1982    328999
# 1983    382143
# 1984    344284
# 1985    345328
# 1986    354281
# 1987    372210
# 1988    424497
# 1989    438246
# 1990    426320
# 1991    376966
# 1992    478205
# 1993    415530
# 1994    402212
# 1995    487700
# 1996    438622
# 1997    441693
# 1998    302075
# 1999    310111
# 2000    315424
# 2001    242561
# 2002    274900
# 2003    230935
# 2004    219048
# 2005    219723
# 2006    253441
# 2007    271418
# 2008    276888
# 2009    304517
# 2010    292707
# 2011    240865
# 2012    251661
# 2013    309129
# 2014    292340
# 2015    372627
# 2016    367710
# 2017    338034
# 2018    315230
# 2019    338085
# 2020    277942
# 2021    309034
# 2022    330532
# 2023    244990
# Name: 경상북도, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename= 'OBS_ASOS_MNH_20240423121211.csv'
df2= pd.read_csv(filename, encoding='cp949')
df2.columns = ['지점', '지점명', '일시', '평균기온', '최고기온', '최저기온', '평균현지기압','평균상대습도', '월합강수량', '평균풍속','일조시간', '최심적설']
df2.insert(3,'년도',df2['일시'].str[:4])

df2 = df2[df2['년도'] != '2024']
df2 = df2[df2['년도'] >= '1980']

kyungbuk_df=df2.query("지점명 in ('안동','구미','김천','문경','상주','영주','영천','예천','의성','청송')")
kb_mean=kyungbuk_df.groupby(['지점명','년도']).mean(numeric_only=True)

kb_mean.head(52)
# Out:
#              지점       평균기온       최고기온      최저기온       평균현지기압     평균상대습도  \
# 지점명 년도
# 구미  1980  279.0  10.916667  24.000000 -0.125000  1011.800000  70.500000
#     1981  279.0  11.308333  23.691667 -0.650000  1011.600000  68.666667
#     1982  279.0  12.291667  24.933333  0.425000  1011.966667  68.833333
#     1983  279.0  12.175000  25.466667  0.158333  1012.300000  71.833333
#     1984  279.0  11.658333  24.808333 -0.116667  1012.483333  67.333333
#     1985  279.0  11.991667  23.800000  1.616667  1011.675000  69.666667
#     1986  279.0  11.400000  24.258333  0.116667  1012.258333  68.083333
#     1987  279.0  11.866667  25.241667  0.533333  1012.416667  68.083333
#     1988  279.0  11.575000  24.858333 -0.100000  1012.016667  66.583333
#     1989  279.0  12.208333  24.016667  0.983333  1012.558333  71.000000
#     1990  279.0  12.550000  24.716667  0.775000  1011.983333  72.416667
#     1991  279.0  11.883333  24.450000  0.100000  1011.533333  69.250000
#     1992  279.0  12.050000  25.083333 -0.250000  1011.916667  72.166667
#     1993  279.0  11.408333  25.000000 -0.350000  1012.391667  72.916667
#     1994  279.0  13.008333  26.225000  0.508333  1012.133333  62.250000
#     1995  279.0  12.241667  25.183333  1.133333  1011.108333  69.083333
#     1996  279.0  12.325000  25.208333  0.425000  1011.425000  62.583333
#     1997  279.0  13.000000  26.975000  0.841667  1011.141667  65.666667
#     1998  279.0  13.650000  26.708333  2.200000  1011.500000  63.333333
#     1999  279.0  13.050000  25.100000  2.266667  1011.041667  61.416667
#     2000  279.0  12.841667  25.508333  1.900000  1010.950000  61.916667
#     2001  279.0  13.000000  25.525000  1.683333  1011.200000  59.750000
#     2002  279.0  12.991667  26.016667  2.150000  1010.800000  58.250000
#     2003  279.0  12.800000  25.000000  1.775000  1011.341667  66.166667
#     2004  279.0  13.641667  26.533333  2.600000  1010.975000  59.000000
#     2005  279.0  12.625000  25.633333  1.491667  1010.016667  63.250000
#     2006  279.0  13.016667  25.483333  2.091667  1010.183333  65.250000
#     2011  100.358333  1.733333  170.625000   5.200000
#     2012  109.133333  1.758333  196.775000        NaN
#     2013   74.600000  1.691667  211.416667        NaN
#     2014  101.900000  1.566667  189.341667        NaN
#     2015   64.916667  1.483333  187.191667        NaN
#     2016  100.666667  1.208333  167.125000        NaN
#     2017   57.383333  1.216667  195.083333        NaN
#     2018  117.508333  1.125000  192.541667        NaN
#     2019   94.433333  1.050000  191.216667        NaN
#     2020  122.458333  1.058333  187.891667        NaN
#     2021   91.500000  0.916667  181.266667        NaN
#     2022   66.075000  0.883333  198.066667        NaN
#     2023  147.716667  0.741667  185.808333        NaN
# 문경  1980  113.716667  1.516667  223.141667   4.650000
#     1981   79.425000  1.541667  231.841667   8.800000
#     1982   61.991667  1.300000  233.300000   6.400000
#     1983   95.650000  1.358333  222.291667   3.080000
#     1984   84.133333  1.358333  229.283333   6.075000
#     1985  108.108333  1.300000  211.033333   4.120000
#     1986   94.733333  1.400000  217.491667   8.950000
#     1987  136.841667  1.325000  215.375000   4.850000

# %%
# 경남 지점 연도별 그룹핑하기
df_kn = df2.query(" 지점명 in ('안동','구미','김천','문경','상주','영주','영천','예천','의성','청송') ")
df_kn = df_kn.groupby(['년도']).aggregate({'평균기온':'mean'}).reset_index()
df_kn


X = df_kn.년도
Y = df_kn.평균기온

plt.rcParams['figure.figsize']=(13,10)
# 경남 지점 평균 구하기
plt.plot(X, Y, '^', linestyle='solid', label='평균기온(°C)')

plt.title('경남 지점 평균기온', fontsize=20)
plt.xlabel('년도')
plt.ylabel('평균기온')
plt.xticks(rotation=45)
plt.grid()
plt.show()


print(X)
print(Y)

print(kb_y)
# Out:
# 0     1980
# 1     1981
# 2     1982
# 3     1983
# 4     1984
# 5     1985
# 6     1986
# 7     1987
# 8     1988
# 9     1989
# 10    1990
# 11    1991
# 12    1992
# 13    1993
# 14    1994
# 15    1995
# 16    1996
# 17    1997
# 18    1998
# 19    1999
# 20    2000
# 21    2001
# 22    2002
# 23    2003
# 24    2004
# 25    2005
# 26    2006
# 27    2007
# 28    2008
# 29    2009
# 30    2010
# 31    2011
# 32    2012
# 33    2013
# 34    2014
# 35    2015
# 36    2016
# 37    2017
# 38    2018
# 39    2019
# 40    2020
# 41    2021
# 42    2022
# 43    2023
# Name: 년도, dtype: object
# 0     10.786667
# 1     11.143333
# 2     11.943333
# 3     11.694444
# 4     11.225000
# 5     11.551389
# 6     10.963889
# 7     11.563889
# 8     11.184722
# 9     12.029167
# 10    12.315278
# 11    11.443056
# 12    11.654167
# 13    11.076389
# 14    12.619444
# 15    11.398611
# 16    11.572222
# 17    12.168056
# 18    12.843056
# 19    12.158333
# 20    12.044444
# 21    11.856944
# 22    11.839286
# 23    11.753571
# 24    12.528571
# 25    11.746429
# 26    12.261905
# 27    12.635714
# 28    12.373810
# 29    12.465476
# 30    11.996429
# 31    11.991667
# 32    11.811905
# 33    12.402381
# 34    12.480952
# 35    13.039286
# 36    13.201190
# 37    12.746429
# 38    12.727381
# 39    13.194048
# 40    12.795238
# 41    12.857143
# 42    12.767857
# 43    13.413095
# Name: 평균기온, dtype: float64
# 1980    256590
# 1981    341237
# 1982    328999
# 1983    382143
# 1984    344284
# 1985    345328
# 1986    354281
# 1987    372210
# 1988    424497
# 1989    438246
# 1990    426320
# 1991    376966
# 1992    478205
# 1993    415530
# 1994    402212
# 1995    487700
# 1996    438622
# 1997    441693
# 1998    302075
# 1999    310111
# 2000    315424
# 2001    242561
# 2002    274900
# 2003    230935
# 2004    219048
# 2005    219723
# 2006    253441
# 2007    271418
# 2008    276888
# 2009    304517
# 2010    292707
# 2011    240865
# 2012    251661
# 2013    309129
# 2014    292340
# 2015    372627
# 2016    367710
# 2017    338034
# 2018    315230
# 2019    338085
# 2020    277942
# 2021    309034
# 2022    330532
# 2023    244990
# Name: 경상북도, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax1 = plt.subplots()

# 이중 y축 설정
ax2 = ax1.twinx()

kb_y.reset_index
print(kb_y)
print(Y)

# 데이터 플로팅
ax1.plot(X, Y,'^',c='y',linestyle='solid')
ax2.plot(X, kb_y,'o',c='b',linestyle='solid')


print(kb_y)
# 레이블 설정
ax1.set_xlabel('년도')
ax1.set_ylabel('기온평균', color='y')
ax2.set_ylabel('생산량', color='b')

plt.figure(figsize=(13, 10))
plt.show()
# Out:
# 1980    256590
# 1981    341237
# 1982    328999
# 1983    382143
# 1984    344284
# 1985    345328
# 1986    354281
# 1987    372210
# 1988    424497
# 1989    438246
# 1990    426320
# 1991    376966
# 1992    478205
# 1993    415530
# 1994    402212
# 1995    487700
# 1996    438622
# 1997    441693
# 1998    302075
# 1999    310111
# 2000    315424
# 2001    242561
# 2002    274900
# 2003    230935
# 2004    219048
# 2005    219723
# 2006    253441
# 2007    271418
# 2008    276888
# 2009    304517
# 2010    292707
# 2011    240865
# 2012    251661
# 2013    309129
# 2014    292340
# 2015    372627
# 2016    367710
# 2017    338034
# 2018    315230
# 2019    338085
# 2020    277942
# 2021    309034
# 2022    330532
# 2023    244990
# Name: 경상북도, dtype: int64
# 0     10.786667
# 1     11.143333
# 2     11.943333
# 3     11.694444
# 4     11.225000
# 5     11.551389
# 6     10.963889
# 7     11.563889
# 8     11.184722
# 9     12.029167
# 10    12.315278
# 11    11.443056
# 12    11.654167
# 13    11.076389
# 14    12.619444
# 15    11.398611
# 16    11.572222
# 17    12.168056
# 18    12.843056
# 19    12.158333
# 20    12.044444
# 21    11.856944
# 22    11.839286
# 23    11.753571
# 24    12.528571
# 25    11.746429
# 26    12.261905
# 27    12.635714
# 28    12.373810
# 29    12.465476
# 30    11.996429
# 31    11.991667
# 32    11.811905
# 33    12.402381
# 34    12.480952
# 35    13.039286
# 36    13.201190
# 37    12.746429
# 38    12.727381
# 39    13.194048
# 40    12.795238
# 41    12.857143
# 42    12.767857
# 43    13.413095
# Name: 평균기온, dtype: float64
# 1980    256590
# 1981    341237
# 1982    328999
# 1983    382143
# 1984    344284
# 1985    345328
# 1986    354281
# 1987    372210
# 1988    424497
# 1989    438246
# 1990    426320
# 1991    376966
# 1992    478205
# 1993    415530
# 1994    402212
# 1995    487700
# 1996    438622
# 1997    441693
# 1998    302075
# 1999    310111
# 2000    315424
# 2001    242561
# 2002    274900
# 2003    230935
# 2004    219048
# 2005    219723
# 2006    253441
# 2007    271418
# 2008    276888
# 2009    304517
# 2010    292707
# 2011    240865
# 2012    251661
# 2013    309129
# 2014    292340
# 2015    372627
# 2016    367710
# 2017    338034
# 2018    315230
# 2019    338085
# 2020    277942
# 2021    309034
# 2022    330532
# 2023    244990
# Name: 경상북도, dtype: int64
